# %%
import pandas as pd
import numpy as np

# %%
file1 = pd.read_csv('file1.csv')
file2 = pd.read_csv('file2.csv')
file3 = pd.read_csv('file3.csv')

# %%
file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %%
file1.head()
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    Vehicle Class  Total Claim Amount
# ...

# %%
file2.head()
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       Policy Type  Vehicle Class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# ...

# %%
cols = [col_name.lower().replace(' ', '_') for col_name in file1.columns]

# %%
cols
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'vehicle_class',
#  'total_claim_amount']

# %%
file1.columns = cols

# %%
file1 = file1.rename(columns={"st":"state"})

# %%
cols2 = [col_name.lower().replace(' ', '_') for col_name in file2.columns]
cols3 = [col_name.lower().replace(' ', '_') for col_name in file3.columns]

# %%
file2.columns = cols2
file3.columns = cols3

# %%
file2 = file2.rename(columns={"st":"state"})
file3 = file3.rename(columns={"st":"state"})

# %%
file1.head()
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# ...

# %%
file2.head()
# Out:
#   customer       state gender education customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
#
#    monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# 0                    88                    1/0/00               633.6
# 1                   114                    1/0/00               547.2
# 2                   112                    1/0/00               537.6
# 3                   214                    1/1/00              1027.2
# 4                    94                    1/0/00               451.2
#
#       policy_type  vehicle_class
# 0   Personal Auto  Four-Door Car
# 1    Special Auto            SUV
# ...

# %%
file3.head()
# Out:
#   customer       state  customer_lifetime_value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    income  monthly_premium_auto  number_of_open_complaints    policy_type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    total_claim_amount  vehicle_class
# ...

# %%
data = pd.concat([file1, file2, file3])

# %%
data.shape
# Out:
# (12074, 11)

# %%
data.tail()
# Out:
#      customer       state gender education customer_lifetime_value   income  \
# 7065  LA72316  California      M  Bachelor             23405.98798  71941.0
# 7066  PK87824  California      F   College             3096.511217  21604.0
# 7067  TD14365  California      M  Bachelor             8163.890428      0.0
# 7068  UP19263  California      M   College             7524.442436  21941.0
# 7069  Y167826  California      M   College             2611.836866      0.0
#
#       monthly_premium_auto number_of_open_complaints     policy_type  \
# 7065                  73.0                         0   Personal Auto
# 7066                  79.0                         0  Corporate Auto
# 7067                  85.0                         3  Corporate Auto
# 7068                  96.0                         0   Personal Auto
# 7069                  77.0                         0  Corporate Auto
#
#       vehicle_class  total_claim_amount
# 7065  Four-Door Car          198.234764
# ...

# %%
data['gender'] = data['gender'].str.lower()

# %%
data.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9137 non-null   object
#  1   state                      9137 non-null   object
#  2   gender                     9015 non-null   object
#  3   education                  9137 non-null   object
#  4   customer_lifetime_value    9130 non-null   object
#  5   income                     9137 non-null   float64
#  6   monthly_premium_auto       9137 non-null   float64
#  7   number_of_open_complaints  9137 non-null   object
#  8   policy_type                9137 non-null   object
#  9   vehicle_class              9137 non-null   object
#  10  total_claim_amount         9137 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 1.1+ MB

# %%
data.describe()
# Out:
#              income  monthly_premium_auto  total_claim_amount
# count   9137.000000           9137.000000         9137.000000
# mean   37828.820291            110.391266          430.527140
# std    30358.716159            581.376032          289.582968
# min        0.000000             61.000000            0.099007
# 25%        0.000000             68.000000          266.996814
# 50%    34244.000000             83.000000          377.561463
# 75%    62447.000000            109.000000          546.420009
# max    99981.000000          35354.000000         2893.239678

# %%
#income, monthly premium auto and total claim amount are numerical when the others columns are categorical

# %%
data.drop('education', inplace=True, axis=1)

# %%
data.head()
# Out:
#   customer       state gender customer_lifetime_value   income  \
# 0  RB50392  Washington    NaN                     NaN      0.0
# 1  QZ44356     Arizona      f              697953.59%      0.0
# 2  AI49188      Nevada      f             1288743.17%  48767.0
# 3  WW63253  California      m              764586.18%      0.0
# 4  GA49547  Washington      m              536307.65%  36357.0
#
#    monthly_premium_auto number_of_open_complaints     policy_type  \
# 0                1000.0                    1/0/00   Personal Auto
# 1                  94.0                    1/0/00   Personal Auto
# 2                 108.0                    1/0/00   Personal Auto
# 3                 106.0                    1/0/00  Corporate Auto
# 4                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935
# 2   Two-Door Car          566.472247
# ...

# %%
data.drop('number_of_open_complaints', inplace=True, axis=1)

# %%
data.head()
# Out:
#   customer       state gender customer_lifetime_value   income  \
# 0  RB50392  Washington    NaN                     NaN      0.0
# 1  QZ44356     Arizona      f              697953.59%      0.0
# 2  AI49188      Nevada      f             1288743.17%  48767.0
# 3  WW63253  California      m              764586.18%      0.0
# 4  GA49547  Washington      m              536307.65%  36357.0
#
#    monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                1000.0   Personal Auto  Four-Door Car            2.704934
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323

# %%
data.isna().sum()
# Out:
# customer                   2937
# state                      2937
# gender                     3059
# customer_lifetime_value    2944
# income                     2937
# monthly_premium_auto       2937
# policy_type                2937
# vehicle_class              2937
# total_claim_amount         2937
# dtype: int64

# %%
data.fillna(0)
# Out:
#      customer       state gender customer_lifetime_value   income  \
# 0     RB50392  Washington      0                       0      0.0
# 1     QZ44356     Arizona      f              697953.59%      0.0
# 2     AI49188      Nevada      f             1288743.17%  48767.0
# 3     WW63253  California      m              764586.18%      0.0
# 4     GA49547  Washington      m              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      m             23405.98798  71941.0
# 7066  PK87824  California      f             3096.511217  21604.0
# 7067  TD14365  California      m             8163.890428      0.0
# 7068  UP19263  California      m             7524.442436  21941.0
# 7069  Y167826  California      m             2611.836866      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %%
clv=data["customer_lifetime_value"]*100

# %%
clv
# Out:
# 0                                                     NaN
# 1       697953.59%697953.59%697953.59%697953.59%697953...
# 2       1288743.17%1288743.17%1288743.17%1288743.17%12...
# 3       764586.18%764586.18%764586.18%764586.18%764586...
# 4       536307.65%536307.65%536307.65%536307.65%536307...
#                               ...
# 7065                                          2340598.798
# 7066                                          309651.1217
# 7067                                          816389.0428
# 7068                                          752444.2436
# 7069                                          261183.6866
# Name: customer_lifetime_value, Length: 12074, dtype: object

# %%
data2=data.dropna()
data2=data.dropna(axis=0)

# %%
data2.head()
# Out:
#   customer       state gender customer_lifetime_value   income  \
# 1  QZ44356     Arizona      f              697953.59%      0.0
# 2  AI49188      Nevada      f             1288743.17%  48767.0
# 3  WW63253  California      m              764586.18%      0.0
# 4  GA49547  Washington      m              536307.65%  36357.0
# 5  OC83172      Oregon      f              825629.78%  62902.0
#
#    monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 1                  94.0   Personal Auto  Four-Door Car         1131.464935
# 2                 108.0   Personal Auto   Two-Door Car          566.472247
# 3                 106.0  Corporate Auto            SUV          529.881344
# 4                  68.0   Personal Auto  Four-Door Car           17.269323
# 5                  69.0   Personal Auto   Two-Door Car          159.383042

# %%
data2.columns
# Out:
# Index(['customer', 'state', 'gender', 'customer_lifetime_value', 'income',
#        'monthly_premium_auto', 'policy_type', 'vehicle_class',
#        'total_claim_amount'],
#       dtype='object')

# %%
data2['customer_lifetime_value'] = data2['customer_lifetime_value'].replace({'\%': ''})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/2n/45mrq41x2yq_l53c6v6v5qnc0000gn/T/ipykernel_23541/2816193632.py in <module>
# ----> 1 data3['customer_lifetime_value'] = data2['customer_lifetime_value'].replace({'\%': ''})
#
# NameError: name 'data3' is not defined

# %%
data2['customer_lifetime_value'] = data2['customer_lifetime_value'].astype('float')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2n/45mrq41x2yq_l53c6v6v5qnc0000gn/T/ipykernel_23541/79838339.py in <module>
# ----> 1 data2['customer_lifetime_value'] = data2['customer_lifetime_value'].astype('float')
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5913             return self._constructor(new_data).__finalize__(self, method="astype")
#    5914
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     417
#     418     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# ...

# %%
data2 = data2.astype({'customer_lifetime_value':'int'})
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/folders/2n/45mrq41x2yq_l53c6v6v5qnc0000gn/T/ipykernel_23541/873891978.py in <module>
# ----> 1 data2 = data2.astype({'customer_lifetime_value':'int'})
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5896                     res_col = col.copy() if copy else col
#    5897                 else:
# -> 5898                     res_col = col.astype(dtype=cdt, copy=copy, errors=errors)
#    5899                 results.append(res_col)
#    5900
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    5910         else:
#    5911             # else, only a single dtype is given
# -> 5912             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
# ...

# %%
data3 = data2.drop_duplicates()

# %%
data3.shape
# Out:
# (9007, 9)

# %%
data2.shape
# Out:
# (9010, 9)

# %%
data4[data4["income"]<1]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index_class_helper.pxi in pandas._libs.index.Int64Engine._check_type()
#
# KeyError: 'income'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/2n/45mrq41x2yq_l53c6v6v5qnc0000gn/T/ipykernel_23541/1816392842.py in <module>
# ...
