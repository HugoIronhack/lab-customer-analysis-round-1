# %%
import pandas as pd

# %%
import numpy as np

# %%
file1 = pd.read_csv('file1.csv')

# %%
file2 = pd.read_csv('file2.csv')

# %%
file3 = pd.read_csv('file3.csv')

# %%
file1.shape
# Out:
# (4008, 11)

# %%
file2.shape
# Out:
# (996, 11)

# %%
file3.shape
# Out:
# (7070, 11)

# %%
file1
# Out:
#      Customer          ST GENDER             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      Number of Open Complaints     Policy Type  Vehicle Class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       Total Claim Amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %%
cols = [col_name.lower().replace(' ', '_') for col_name in file1.columns]

# %%
cols
# Out:
# ['customer',
#  'st',
#  'gender',
#  'education',
#  'customer_lifetime_value',
#  'income',
#  'monthly_premium_auto',
#  'number_of_open_complaints',
#  'policy_type',
#  'vehicle_class',
#  'total_claim_amount']

# %%
file1.columns = cols

# %%
file1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      number_of_open_complaints     policy_type  vehicle_class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       total_claim_amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %%
file1 = file1.rename(columns={"st":"state"})

# %%
file1
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      number_of_open_complaints     policy_type  vehicle_class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       total_claim_amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %%
cols2 = [col_name.lower().replace(' ', '_') for col_name in file2.columns]
cols3 = [col_name.lower().replace(' ', '_') for col_name in file3.columns]

# %%
file2.columns = cols2
file2.columns = cols3

# %%
file2 = file2.rename(columns={"st":"state"})
file3 = file3.rename(columns={"st":"state"})

# %%
file1.head()
# Out:
#   customer       state gender             education customer_lifetime_value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
#
#     income  monthly_premium_auto number_of_open_complaints     policy_type  \
# 0      0.0                1000.0                    1/0/00   Personal Auto
# 1      0.0                  94.0                    1/0/00   Personal Auto
# 2  48767.0                 108.0                    1/0/00   Personal Auto
# 3      0.0                 106.0                    1/0/00  Corporate Auto
# 4  36357.0                  68.0                    1/0/00   Personal Auto
#
#    vehicle_class  total_claim_amount
# 0  Four-Door Car            2.704934
# 1  Four-Door Car         1131.464935
# 2   Two-Door Car          566.472247
# 3            SUV          529.881344
# 4  Four-Door Car           17.269323

# %%
file2.head()
# Out:
#   customer       state customer_lifetime_value education       gender  income  \
# 0  GS98873     Arizona                       F  Bachelor   323912.47%   16061
# 1  CW49887  California                       F    Master   462680.11%   79487
# 2  MY31220  California                       F   College   899704.02%   54230
# 3  UH35128      Oregon                       F   College  2580706.30%   71210
# 4  WH52799     Arizona                       F   College   380812.21%   94903
#
#    monthly_premium_auto number_of_open_complaints  policy_type  \
# 0                    88                    1/0/00        633.6
# 1                   114                    1/0/00        547.2
# 2                   112                    1/0/00        537.6
# 3                   214                    1/1/00       1027.2
# 4                    94                    1/0/00        451.2
#
#   total_claim_amount  vehicle_class
# 0      Personal Auto  Four-Door Car
# 1       Special Auto            SUV
# 2      Personal Auto   Two-Door Car
# 3      Personal Auto     Luxury Car
# 4     Corporate Auto   Two-Door Car

# %%
file3.head()
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
#
#    Income  Monthly Premium Auto  Number of Open Complaints    Policy Type  \
# 0       0                   104                          0  Personal Auto
# 1       0                    66                          0  Personal Auto
# 2   25820                    82                          0  Personal Auto
# 3       0                   121                          0  Personal Auto
# 4   30366                   101                          2  Personal Auto
#
#    Total Claim Amount  Vehicle Class
# 0          499.200000   Two-Door Car
# 1            3.468912   Two-Door Car
# 2          393.600000  Four-Door Car
# 3          699.615192            SUV
# 4          484.800000            SUV

# %%
file1.columns
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
data1=file1.columns

# %%
data1
# Out:
# Index(['customer', 'state', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
data11=file1[data1]

# %%
data11
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 4003                     NaN      NaN                   NaN
# 4004                     NaN      NaN                   NaN
# 4005                     NaN      NaN                   NaN
# 4006                     NaN      NaN                   NaN
# 4007                     NaN      NaN                   NaN
#
#      number_of_open_complaints     policy_type  vehicle_class  \
# 0                       1/0/00   Personal Auto  Four-Door Car
# 1                       1/0/00   Personal Auto  Four-Door Car
# 2                       1/0/00   Personal Auto   Two-Door Car
# 3                       1/0/00  Corporate Auto            SUV
# 4                       1/0/00   Personal Auto  Four-Door Car
# ...                        ...             ...            ...
# 4003                       NaN             NaN            NaN
# 4004                       NaN             NaN            NaN
# 4005                       NaN             NaN            NaN
# 4006                       NaN             NaN            NaN
# 4007                       NaN             NaN            NaN
#
#       total_claim_amount
# 0               2.704934
# 1            1131.464935
# 2             566.472247
# 3             529.881344
# 4              17.269323
# ...                  ...
# 4003                 NaN
# 4004                 NaN
# 4005                 NaN
# 4006                 NaN
# 4007                 NaN
#
# [4008 rows x 11 columns]

# %%
data = pd.concat([file1, file2, file3])

# %%
data
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065      NaN         NaN    NaN                   NaN
# 7066      NaN         NaN    NaN                   NaN
# 7067      NaN         NaN    NaN                   NaN
# 7068      NaN         NaN    NaN                   NaN
# 7069      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# 3                 764586.18%      0.0                 106.0
# 4                 536307.65%  36357.0                  68.0
# ...                      ...      ...                   ...
# 7065                     NaN      NaN                   NaN
# 7066                     NaN      NaN                   NaN
# 7067                     NaN      NaN                   NaN
# 7068                     NaN      NaN                   NaN
# 7069                     NaN      NaN                   NaN
#
#      number_of_open_complaints     policy_type  vehicle_class  ...  \
# 0                       1/0/00   Personal Auto  Four-Door Car  ...
# 1                       1/0/00   Personal Auto  Four-Door Car  ...
# 2                       1/0/00   Personal Auto   Two-Door Car  ...
# 3                       1/0/00  Corporate Auto            SUV  ...
# 4                       1/0/00   Personal Auto  Four-Door Car  ...
# ...                        ...             ...            ...  ...
# 7065                       NaN             NaN            NaN  ...
# 7066                       NaN             NaN            NaN  ...
# 7067                       NaN             NaN            NaN  ...
# 7068                       NaN             NaN            NaN  ...
# 7069                       NaN             NaN            NaN  ...
#
#            State Customer Lifetime Value Education  Gender   Income  \
# 0            NaN                     NaN       NaN     NaN      NaN
# 1            NaN                     NaN       NaN     NaN      NaN
# 2            NaN                     NaN       NaN     NaN      NaN
# 3            NaN                     NaN       NaN     NaN      NaN
# 4            NaN                     NaN       NaN     NaN      NaN
# ...          ...                     ...       ...     ...      ...
# 7065  California            23405.987980  Bachelor       M  71941.0
# 7066  California             3096.511217   College       F  21604.0
# 7067  California             8163.890428  Bachelor       M      0.0
# 7068  California             7524.442436   College       M  21941.0
# 7069  California             2611.836866   College       M      0.0
#
#      Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# 0                     NaN                        NaN             NaN
# 1                     NaN                        NaN             NaN
# 2                     NaN                        NaN             NaN
# 3                     NaN                        NaN             NaN
# 4                     NaN                        NaN             NaN
# ...                   ...                        ...             ...
# 7065                 73.0                        0.0   Personal Auto
# 7066                 79.0                        0.0  Corporate Auto
# 7067                 85.0                        3.0  Corporate Auto
# 7068                 96.0                        0.0   Personal Auto
# 7069                 77.0                        0.0  Corporate Auto
#
#       Total Claim Amount  Vehicle Class
# 0                    NaN            NaN
# 1                    NaN            NaN
# 2                    NaN            NaN
# 3                    NaN            NaN
# 4                    NaN            NaN
# ...                  ...            ...
# 7065          198.234764  Four-Door Car
# 7066          379.200000  Four-Door Car
# 7067          790.784983  Four-Door Car
# 7068          691.200000  Four-Door Car
# 7069          369.600000   Two-Door Car
#
# [12074 rows x 22 columns]

# %%
data.dtypes
# Out:
# customer                      object
# state                         object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount            object
# Customer                      object
# State                         object
# Customer Lifetime Value      float64
# Education                     object
# Gender                        object
# Income                       float64
# Monthly Premium Auto         float64
# Number of Open Complaints    float64
# Policy Type                   object
# Total Claim Amount           float64
# Vehicle Class                 object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12074 entries, 0 to 7069
# Data columns (total 22 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   2067 non-null   object
#  1   state                      2067 non-null   object
#  2   gender                     1946 non-null   object
#  3   education                  2067 non-null   object
#  4   customer_lifetime_value    2059 non-null   object
#  5   income                     2067 non-null   float64
#  6   monthly_premium_auto       2067 non-null   float64
#  7   number_of_open_complaints  2067 non-null   object
#  8   policy_type                2067 non-null   object
#  9   vehicle_class              2067 non-null   object
#  10  total_claim_amount         2067 non-null   object
#  11  Customer                   7070 non-null   object
#  12  State                      7070 non-null   object
#  13  Customer Lifetime Value    7070 non-null   float64
#  14  Education                  7070 non-null   object
#  15  Gender                     7070 non-null   object
#  16  Income                     7070 non-null   float64
#  17  Monthly Premium Auto       7070 non-null   float64
#  18  Number of Open Complaints  7070 non-null   float64
#  19  Policy Type                7070 non-null   object
#  20  Total Claim Amount         7070 non-null   float64
#  21  Vehicle Class              7070 non-null   object
# dtypes: float64(7), object(15)
# memory usage: 2.1+ MB

# %%
data.select_dtypes(include=np.number)
# Out:
#        income  monthly_premium_auto  Customer Lifetime Value   Income  \
# 0         0.0                1000.0                      NaN      NaN
# 1         0.0                  94.0                      NaN      NaN
# 2     48767.0                 108.0                      NaN      NaN
# 3         0.0                 106.0                      NaN      NaN
# 4     36357.0                  68.0                      NaN      NaN
# ...       ...                   ...                      ...      ...
# 7065      NaN                   NaN             23405.987980  71941.0
# 7066      NaN                   NaN              3096.511217  21604.0
# 7067      NaN                   NaN              8163.890428      0.0
# 7068      NaN                   NaN              7524.442436  21941.0
# 7069      NaN                   NaN              2611.836866      0.0
#
#       Monthly Premium Auto  Number of Open Complaints  Total Claim Amount
# 0                      NaN                        NaN                 NaN
# 1                      NaN                        NaN                 NaN
# 2                      NaN                        NaN                 NaN
# 3                      NaN                        NaN                 NaN
# 4                      NaN                        NaN                 NaN
# ...                    ...                        ...                 ...
# 7065                  73.0                        0.0          198.234764
# 7066                  79.0                        0.0          379.200000
# 7067                  85.0                        3.0          790.784983
# 7068                  96.0                        0.0          691.200000
# 7069                  77.0                        0.0          369.600000
#
# [12074 rows x 7 columns]

# %%
data.select_dtypes(exclude=np.number)
# Out:
#      customer       state gender  \
# 0     RB50392  Washington    NaN
# 1     QZ44356     Arizona      F
# 2     AI49188      Nevada      F
# 3     WW63253  California      M
# 4     GA49547  Washington      M
# ...       ...         ...    ...
# 7065      NaN         NaN    NaN
# 7066      NaN         NaN    NaN
# 7067      NaN         NaN    NaN
# 7068      NaN         NaN    NaN
# 7069      NaN         NaN    NaN
#
#                                 customer_lifetime_value     policy_type  \
# 0                                                   NaN   Personal Auto
# 1     697953.59%697953.59%697953.59%697953.59%697953...   Personal Auto
# 2     1288743.17%1288743.17%1288743.17%1288743.17%12...   Personal Auto
# 3     764586.18%764586.18%764586.18%764586.18%764586...  Corporate Auto
# 4     536307.65%536307.65%536307.65%536307.65%536307...   Personal Auto
# ...                                                 ...             ...
# 7065                                                NaN             NaN
# 7066                                                NaN             NaN
# 7067                                                NaN             NaN
# 7068                                                NaN             NaN
# 7069                                                NaN             NaN
#
#       vehicle_class total_claim_amount Customer       State Education Gender  \
# 0     Four-Door Car           2.704934      NaN         NaN       NaN    NaN
# 1     Four-Door Car        1131.464935      NaN         NaN       NaN    NaN
# 2      Two-Door Car         566.472247      NaN         NaN       NaN    NaN
# 3               SUV         529.881344      NaN         NaN       NaN    NaN
# 4     Four-Door Car          17.269323      NaN         NaN       NaN    NaN
# ...             ...                ...      ...         ...       ...    ...
# 7065            NaN                NaN  LA72316  California  Bachelor      M
# 7066            NaN                NaN  PK87824  California   College      F
# 7067            NaN                NaN  TD14365  California  Bachelor      M
# 7068            NaN                NaN  UP19263  California   College      M
# 7069            NaN                NaN  Y167826  California   College      M
#
#          Policy Type  Vehicle Class
# 0                NaN            NaN
# 1                NaN            NaN
# 2                NaN            NaN
# 3                NaN            NaN
# 4                NaN            NaN
# ...              ...            ...
# 7065   Personal Auto  Four-Door Car
# 7066  Corporate Auto  Four-Door Car
# 7067  Corporate Auto  Four-Door Car
# 7068   Personal Auto  Four-Door Car
# 7069  Corporate Auto   Two-Door Car
#
# [12074 rows x 13 columns]

# %%
data
# Out:
#      customer       state gender  \
# 0     RB50392  Washington    NaN
# 1     QZ44356     Arizona      F
# 2     AI49188      Nevada      F
# 3     WW63253  California      M
# 4     GA49547  Washington      M
# ...       ...         ...    ...
# 7065      NaN         NaN    NaN
# 7066      NaN         NaN    NaN
# 7067      NaN         NaN    NaN
# 7068      NaN         NaN    NaN
# 7069      NaN         NaN    NaN
#
#                                 customer_lifetime_value   income  \
# 0                                                   NaN      0.0
# 1     697953.59%697953.59%697953.59%697953.59%697953...      0.0
# 2     1288743.17%1288743.17%1288743.17%1288743.17%12...  48767.0
# 3     764586.18%764586.18%764586.18%764586.18%764586...      0.0
# 4     536307.65%536307.65%536307.65%536307.65%536307...  36357.0
# ...                                                 ...      ...
# 7065                                                NaN      NaN
# 7066                                                NaN      NaN
# 7067                                                NaN      NaN
# 7068                                                NaN      NaN
# 7069                                                NaN      NaN
#
#       monthly_premium_auto     policy_type  vehicle_class total_claim_amount  \
# 0                   1000.0   Personal Auto  Four-Door Car           2.704934
# 1                     94.0   Personal Auto  Four-Door Car        1131.464935
# 2                    108.0   Personal Auto   Two-Door Car         566.472247
# 3                    106.0  Corporate Auto            SUV         529.881344
# 4                     68.0   Personal Auto  Four-Door Car          17.269323
# ...                    ...             ...            ...                ...
# 7065                   NaN             NaN            NaN                NaN
# 7066                   NaN             NaN            NaN                NaN
# 7067                   NaN             NaN            NaN                NaN
# 7068                   NaN             NaN            NaN                NaN
# 7069                   NaN             NaN            NaN                NaN
#
#      Customer       State  Customer Lifetime Value Education Gender   Income  \
# 0         NaN         NaN                      NaN       NaN    NaN      NaN
# 1         NaN         NaN                      NaN       NaN    NaN      NaN
# 2         NaN         NaN                      NaN       NaN    NaN      NaN
# 3         NaN         NaN                      NaN       NaN    NaN      NaN
# 4         NaN         NaN                      NaN       NaN    NaN      NaN
# ...       ...         ...                      ...       ...    ...      ...
# 7065  LA72316  California             23405.987980  Bachelor      M  71941.0
# 7066  PK87824  California              3096.511217   College      F  21604.0
# 7067  TD14365  California              8163.890428  Bachelor      M      0.0
# 7068  UP19263  California              7524.442436   College      M  21941.0
# 7069  Y167826  California              2611.836866   College      M      0.0
#
#       Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# 0                      NaN                        NaN             NaN
# 1                      NaN                        NaN             NaN
# 2                      NaN                        NaN             NaN
# 3                      NaN                        NaN             NaN
# 4                      NaN                        NaN             NaN
# ...                    ...                        ...             ...
# 7065                  73.0                        0.0   Personal Auto
# 7066                  79.0                        0.0  Corporate Auto
# 7067                  85.0                        3.0  Corporate Auto
# 7068                  96.0                        0.0   Personal Auto
# 7069                  77.0                        0.0  Corporate Auto
#
#       Total Claim Amount  Vehicle Class
# 0                    NaN            NaN
# 1                    NaN            NaN
# 2                    NaN            NaN
# 3                    NaN            NaN
# 4                    NaN            NaN
# ...                  ...            ...
# 7065          198.234764  Four-Door Car
# 7066          379.200000  Four-Door Car
# 7067          790.784983  Four-Door Car
# 7068          691.200000  Four-Door Car
# 7069          369.600000   Two-Door Car
#
# [12074 rows x 20 columns]

# %%
data = pd.concat([file1, file2, file3])

# %%
del data["education"]

# %%
del data["number_of_open_complaints"]

# %%
data
# Out:
#      customer       state gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065      NaN         NaN    NaN                     NaN      NaN
# 7066      NaN         NaN    NaN                     NaN      NaN
# 7067      NaN         NaN    NaN                     NaN      NaN
# 7068      NaN         NaN    NaN                     NaN      NaN
# 7069      NaN         NaN    NaN                     NaN      NaN
#
#       monthly_premium_auto     policy_type  vehicle_class total_claim_amount  \
# 0                   1000.0   Personal Auto  Four-Door Car           2.704934
# 1                     94.0   Personal Auto  Four-Door Car        1131.464935
# 2                    108.0   Personal Auto   Two-Door Car         566.472247
# 3                    106.0  Corporate Auto            SUV         529.881344
# 4                     68.0   Personal Auto  Four-Door Car          17.269323
# ...                    ...             ...            ...                ...
# 7065                   NaN             NaN            NaN                NaN
# 7066                   NaN             NaN            NaN                NaN
# 7067                   NaN             NaN            NaN                NaN
# 7068                   NaN             NaN            NaN                NaN
# 7069                   NaN             NaN            NaN                NaN
#
#      Customer       State  Customer Lifetime Value Education Gender   Income  \
# 0         NaN         NaN                      NaN       NaN    NaN      NaN
# 1         NaN         NaN                      NaN       NaN    NaN      NaN
# 2         NaN         NaN                      NaN       NaN    NaN      NaN
# 3         NaN         NaN                      NaN       NaN    NaN      NaN
# 4         NaN         NaN                      NaN       NaN    NaN      NaN
# ...       ...         ...                      ...       ...    ...      ...
# 7065  LA72316  California             23405.987980  Bachelor      M  71941.0
# 7066  PK87824  California              3096.511217   College      F  21604.0
# 7067  TD14365  California              8163.890428  Bachelor      M      0.0
# 7068  UP19263  California              7524.442436   College      M  21941.0
# 7069  Y167826  California              2611.836866   College      M      0.0
#
#       Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# 0                      NaN                        NaN             NaN
# 1                      NaN                        NaN             NaN
# 2                      NaN                        NaN             NaN
# 3                      NaN                        NaN             NaN
# 4                      NaN                        NaN             NaN
# ...                    ...                        ...             ...
# 7065                  73.0                        0.0   Personal Auto
# 7066                  79.0                        0.0  Corporate Auto
# 7067                  85.0                        3.0  Corporate Auto
# 7068                  96.0                        0.0   Personal Auto
# 7069                  77.0                        0.0  Corporate Auto
#
#       Total Claim Amount  Vehicle Class
# 0                    NaN            NaN
# 1                    NaN            NaN
# 2                    NaN            NaN
# 3                    NaN            NaN
# 4                    NaN            NaN
# ...                  ...            ...
# 7065          198.234764  Four-Door Car
# 7066          379.200000  Four-Door Car
# 7067          790.784983  Four-Door Car
# 7068          691.200000  Four-Door Car
# 7069          369.600000   Two-Door Car
#
# [12074 rows x 20 columns]
